# %%
import pandas as pd
import os

import numpy as np

def clean_file_col(in_df):
       cases = [in_df['file'].str.contains('/')]
       out = [in_df['file'].str.split('/').str[-1]]
       in_df['file'] = np.select(cases,out,in_df['file'])

cr_src=pd.concat(
    [
        pd.read_csv(os.path.join('./cropped_UTK_dataset.csv')),
        pd.read_csv(os.path.join('./uncropped_UTK_dataset.csv'))
    ]
)

crop_src = pd.read_csv(os.path.join('./cropped_UTK_dataset.csv'))

ucrop_src = pd.read_csv(os.path.join('./uncropped_UTK_dataset.csv'))

df_cropped_p_mtcnn = pd.read_csv(os.path.join('./crop_df_p_mtcnn.csv'))
clean_file_col(df_cropped_p_mtcnn)
df_cropped_p_mtcnn=pd.merge(left=crop_src,how='left',right=df_cropped_p_mtcnn)
df_cropped_p_mtcnn['detection_enabled']=True 
df_cropped_p_mtcnn['detection_model'] = 'mtcnn'
df_cropped_p_mtcnn['image_type'] = 'cropped'
df_cropped_p_mtcnn['pred_model'] = 'DeepFace'

df_uncropped_p_mtcnn = pd.read_csv(os.path.join('./uncropped_df_p_mtcnn.csv'))
clean_file_col(df_uncropped_p_mtcnn)
df_uncropped_p_mtcnn=pd.merge(left=ucrop_src,how='left',right=df_uncropped_p_mtcnn)
df_uncropped_p_mtcnn['detection_enabled']=True 
df_uncropped_p_mtcnn['detection_model'] = 'mtcnn'
df_uncropped_p_mtcnn['image_type'] = 'uncropped'
df_uncropped_p_mtcnn['pred_model'] = 'DeepFace'


df_cropped_p_opencv = pd.read_csv(os.path.join('./crop_df_p_opencv.csv'))
clean_file_col(df_cropped_p_opencv)
df_cropped_p_opencv=pd.merge(left=crop_src,how='left',right=df_cropped_p_opencv)
df_cropped_p_opencv['detection_enabled']=True 
df_cropped_p_opencv['detection_model'] = 'opencv'
df_cropped_p_opencv['image_type'] = 'cropped'
df_cropped_p_opencv['pred_model'] = 'DeepFace'


df_uncropped_p_opencv = pd.read_csv(os.path.join('./uncropped_df_p_opencv.csv'))
clean_file_col(df_uncropped_p_opencv)
df_uncropped_p_opencv=pd.merge(left=ucrop_src,how='left',right=df_uncropped_p_opencv)
df_uncropped_p_opencv['detection_enabled']=True 
df_uncropped_p_opencv['detection_model'] = 'opencv'
df_uncropped_p_opencv['image_type'] = 'uncropped'
df_uncropped_p_opencv['pred_model'] = 'DeepFace'

df_cropped_np = pd.read_csv(os.path.join('./crop_df_np.csv'))
clean_file_col(df_cropped_np)
df_cropped_np=pd.merge(left=crop_src,how='left',right=df_cropped_np)
df_cropped_np['detection_enabled']=False
df_cropped_np['detection_model'] = 'None'
df_cropped_np['image_type'] = 'cropped'
df_cropped_np['pred_model'] = 'DeepFace'

df_uncropped_np = pd.read_csv(os.path.join('./uncropped_df_np.csv'))
clean_file_col(df_uncropped_np)
df_uncropped_np=pd.merge(left=ucrop_src,how='left',right=df_uncropped_np)
df_uncropped_np['detection_enabled']=False
df_uncropped_np['detection_model'] = 'None'
df_uncropped_np['image_type'] = 'uncropped'
df_uncropped_np['pred_model'] = 'DeepFace'





#ff_cropped_p = pd.read_csv(os.path.join('./cropped_ff_p.csv'))
ff_cropped_p = pd.read_csv(os.path.join('./new_ff_c_p.csv'))
clean_file_col(ff_cropped_p)
ff_cropped_p=pd.merge(left=crop_src,how='left',right=ff_cropped_p)
ff_cropped_p['detection_enabled']=True
ff_cropped_p['detection_model'] = 'dlib'
ff_cropped_p['image_type'] = 'cropped'
ff_cropped_p['pred_model'] = 'FairFace'
ff_cropped_p=ff_cropped_p[['file','pred_race', 'pred_gender', 'pred_age_grp',
       'pred_age_lower', 'pred_age_upper', 'pred_model', 'detection_enabled',
       'detection_model', 'image_type']]

#ff_uncropped_p = pd.read_csv(os.path.join('./uncropped_ff_p.csv'))
ff_uncropped_p = pd.read_csv(os.path.join('./new_ff_uc_p.csv'))
clean_file_col(ff_uncropped_p)
ff_uncropped_p=pd.merge(left=ucrop_src,how='left',right=ff_uncropped_p)
ff_uncropped_p['detection_enabled']=True
ff_uncropped_p['detection_model'] = 'dlib'
ff_uncropped_p['image_type'] = 'uncropped'
ff_uncropped_p['pred_model'] = 'FairFace'
ff_uncropped_p=ff_uncropped_p[['file','pred_race', 'pred_gender', 'pred_age_grp',
       'pred_age_lower', 'pred_age_upper', 'pred_model', 'detection_enabled',
       'detection_model', 'image_type']]

#ff_cropped_np = pd.read_csv(os.path.join('./cropped_ff_p.csv'))
ff_cropped_np = pd.read_csv(os.path.join('./new_ff_c_p.csv'))
clean_file_col(ff_cropped_np)
ff_cropped_np=pd.merge(left=crop_src,how='left',right=ff_cropped_np)
ff_cropped_np['detection_enabled']=False
ff_cropped_np['detection_model'] = 'None'
ff_cropped_np['image_type'] = 'cropped'
ff_cropped_np['pred_model'] = 'FairFace'
ff_cropped_np=ff_cropped_np[['file','pred_race', 'pred_gender', 'pred_age_grp',
       'pred_age_lower', 'pred_age_upper', 'pred_model', 'detection_enabled',
       'detection_model', 'image_type']]

#ff_uncropped_np = pd.read_csv(os.path.join('./uncropped_ff_np.csv'))
ff_uncropped_np = pd.read_csv(os.path.join('./new_ff_uc_np.csv'))
clean_file_col(ff_uncropped_np)
ff_uncropped_np=pd.merge(left=ucrop_src,how='left',right=ff_uncropped_np)
ff_uncropped_np['detection_enabled']=False
ff_uncropped_np['detection_model'] = 'None'
ff_uncropped_np['image_type'] = 'uncropped'
ff_uncropped_np['pred_model'] = 'FairFace'
ff_uncropped_np=ff_uncropped_np[['file','pred_race', 'pred_gender', 'pred_age_grp',
       'pred_age_lower', 'pred_age_upper', 'pred_model', 'detection_enabled',
       'detection_model', 'image_type']]

# %%
#df_cropped_p_mtcnn
display(
    len(df_cropped_np),
    len(df_cropped_p_mtcnn),
    len(df_cropped_p_opencv),
    len(df_uncropped_np),
    len(df_uncropped_p_mtcnn),
    len(df_uncropped_p_opencv),
    len(ff_cropped_np),
    len(ff_cropped_p),
    len(ff_uncropped_np),
    len(ff_uncropped_p)
)
ff_cropped_np
# Out:
# 9780
# 9780
# 9780
# 9780
# 9780
# 9780
# 9780
# 9780
# 9780
# 9780
#                                        file pred_race pred_gender  \
# 0      9_1_2_20161219204347420.jpg.chip.jpg     Asian      Female
# 1      1_1_2_20161219154612988.jpg.chip.jpg     White        Male
# 2     16_0_0_20170104003740977.jpg.chip.jpg     White        Male
# 3      1_1_3_20161219230734016.jpg.chip.jpg     Other        Male
# 4     26_1_1_20170103181931657.jpg.chip.jpg     Black      Female
# ...                                     ...       ...         ...
# 9775  16_1_0_20170109212413425.jpg.chip.jpg     White      Female
# 9776   1_1_3_20161219224454728.jpg.chip.jpg     Other        Male
# 9777  71_0_0_20170104185305424.jpg.chip.jpg     White        Male
# 9778  54_0_0_20170109010040814.jpg.chip.jpg     White        Male
# 9779  36_0_0_20170104181520477.jpg.chip.jpg     White        Male
#
#      pred_age_grp  pred_age_lower  pred_age_upper pred_model  \
# 0           20-29            20.0            29.0   FairFace
# 1             0-2             0.0             2.0   FairFace
# 2           10-19            10.0            19.0   FairFace
# 3             0-2             0.0             2.0   FairFace
# 4           20-29            20.0            29.0   FairFace
# ...           ...             ...             ...        ...
# 9775        20-29            20.0            29.0   FairFace
# 9776          0-2             0.0             2.0   FairFace
# 9777        60-69            60.0            69.0   FairFace
# 9778        40-49            40.0            49.0   FairFace
# 9779        30-39            30.0            39.0   FairFace
#
#       detection_enabled detection_model image_type
# 0                 False            None    cropped
# 1                 False            None    cropped
# 2                 False            None    cropped
# 3                 False            None    cropped
# 4                 False            None    cropped
# ...                 ...             ...        ...
# 9775              False            None    cropped
# 9776              False            None    cropped
# 9777              False            None    cropped
# 9778              False            None    cropped
# 9779              False            None    cropped
#
# [9780 rows x 10 columns]

# %%
MasterFrame = pd.concat(
   [df_cropped_p_mtcnn,df_uncropped_p_mtcnn,df_cropped_p_opencv,df_uncropped_p_opencv,
    df_cropped_np,df_uncropped_np,ff_cropped_p,ff_uncropped_p,ff_cropped_np,ff_uncropped_np] 
)

MasterFrame['slash'] = MasterFrame['file'].str.contains('/')

import numpy as np
cases = [MasterFrame['file'].str.contains('/')]
out = [MasterFrame['file'].str.split('/').str[-1]]
MasterFrame['file'] = np.select(cases,out,MasterFrame['file'])

MasterFrame['pred_race']=np.where(MasterFrame['pred_race']=='latino hispanic',"Other",MasterFrame['pred_race'])

# %%
MasterFrame = MasterFrame.drop(labels=['img_path','Unnamed: 0','img_path_x','slash'],axis=1)

# %%
MasterFrame
# Out:
#                                        file pred_race pred_gender  \
# 0      9_1_2_20161219204347420.jpg.chip.jpg     Asian        Male
# 1      1_1_2_20161219154612988.jpg.chip.jpg     Asian        Male
# 2     16_0_0_20170104003740977.jpg.chip.jpg     Other        Male
# 3      1_1_3_20161219230734016.jpg.chip.jpg     Asian        Male
# 4     26_1_1_20170103181931657.jpg.chip.jpg     Black      Female
# ...                                     ...       ...         ...
# 9775           16_1_0_20170109212413425.jpg     White      Female
# 9776            1_1_3_20161219224454728.jpg     Other        Male
# 9777           71_0_0_20170104185305424.jpg     Asian        Male
# 9778           54_0_0_20170109010040814.jpg     Asian        Male
# 9779           36_0_0_20170104181520477.jpg     White        Male
#
#      pred_age_grp  pred_age_lower  pred_age_upper pred_model  \
# 0           30-39            30.0            39.0   DeepFace
# 1           20-29            20.0            29.0   DeepFace
# 2           20-29            20.0            29.0   DeepFace
# 3           30-39            30.0            39.0   DeepFace
# 4           20-29            20.0            29.0   DeepFace
# ...           ...             ...             ...        ...
# 9775        20-29            20.0            29.0   FairFace
# 9776          0-2             0.0             2.0   FairFace
# 9777        60-69            60.0            69.0   FairFace
# 9778        30-39            30.0            39.0   FairFace
# 9779        30-39            30.0            39.0   FairFace
#
#       detection_enabled detection_model image_type
# 0                  True           mtcnn    cropped
# 1                  True           mtcnn    cropped
# 2                  True           mtcnn    cropped
# 3                  True           mtcnn    cropped
# 4                  True           mtcnn    cropped
# ...                 ...             ...        ...
# 9775              False            None  uncropped
# 9776              False            None  uncropped
# 9777              False            None  uncropped
# 9778              False            None  uncropped
# 9779              False            None  uncropped
#
# [97800 rows x 10 columns]

# %%
#MasterFrame = MasterFrame.drop(labels=['src_age','src_gender','src_race','src_timestamp'],axis=1)
MasterFrame[['src_age','src_gender','src_race','src_timestamp']] = MasterFrame['file'].str.split('.').str[0].str.split('_',expand=True)
cases=[MasterFrame['src_gender']=='0',MasterFrame['src_gender']=='1']
out=["Male","Female"] 
MasterFrame['src_gender']=np.select(cases,out,MasterFrame['src_gender'])
cases=[MasterFrame['src_race']=='0',MasterFrame['src_race']=='1',
       MasterFrame['src_race']=='2',MasterFrame['src_race']=='3',
       MasterFrame['src_race']=='4']
out=["White","Black","Asian","Indian","Other"]
MasterFrame['src_race']=np.select(cases,out,MasterFrame['src_race'])
MasterFrame['src_age'] = MasterFrame['src_age'].astype(int)

b = [0, 3, 10, 20, 30, 40, 50, 60, 70, np.inf]
group_names = ["0-2", "3-9", "10-19", "20-29", "30-39", "40-49", "50-59", "60-69", "70-130"]
MasterFrame['src_age_grp'] = pd.cut(MasterFrame['src_age'],bins=b,labels=group_names)

#MasterFrame=MasterFrame.drop(labels=['img_path'],axis=1)

# %%
MasterFrame
# Out:
#                                        file pred_race pred_gender  \
# 0      9_1_2_20161219204347420.jpg.chip.jpg     Asian        Male
# 1      1_1_2_20161219154612988.jpg.chip.jpg     Asian        Male
# 2     16_0_0_20170104003740977.jpg.chip.jpg     Other        Male
# 3      1_1_3_20161219230734016.jpg.chip.jpg     Asian        Male
# 4     26_1_1_20170103181931657.jpg.chip.jpg     Black      Female
# ...                                     ...       ...         ...
# 9775           16_1_0_20170109212413425.jpg     White      Female
# 9776            1_1_3_20161219224454728.jpg     Other        Male
# 9777           71_0_0_20170104185305424.jpg     Asian        Male
# 9778           54_0_0_20170109010040814.jpg     Asian        Male
# 9779           36_0_0_20170104181520477.jpg     White        Male
#
#      pred_age_grp  pred_age_lower  pred_age_upper pred_model  \
# 0           30-39            30.0            39.0   DeepFace
# 1           20-29            20.0            29.0   DeepFace
# 2           20-29            20.0            29.0   DeepFace
# 3           30-39            30.0            39.0   DeepFace
# 4           20-29            20.0            29.0   DeepFace
# ...           ...             ...             ...        ...
# 9775        20-29            20.0            29.0   FairFace
# 9776          0-2             0.0             2.0   FairFace
# 9777        60-69            60.0            69.0   FairFace
# 9778        30-39            30.0            39.0   FairFace
# 9779        30-39            30.0            39.0   FairFace
#
#       detection_enabled detection_model image_type  src_age src_gender  \
# 0                  True           mtcnn    cropped        9     Female
# 1                  True           mtcnn    cropped        1     Female
# 2                  True           mtcnn    cropped       16       Male
# 3                  True           mtcnn    cropped        1     Female
# 4                  True           mtcnn    cropped       26     Female
# ...                 ...             ...        ...      ...        ...
# 9775              False            None  uncropped       16     Female
# 9776              False            None  uncropped        1     Female
# 9777              False            None  uncropped       71       Male
# 9778              False            None  uncropped       54       Male
# 9779              False            None  uncropped       36       Male
#
#      src_race      src_timestamp src_age_grp
# 0       Asian  20161219204347420         3-9
# 1       Asian  20161219154612988         0-2
# 2       White  20170104003740977       10-19
# 3      Indian  20161219230734016         0-2
# 4       Black  20170103181931657       20-29
# ...       ...                ...         ...
# 9775    White  20170109212413425       10-19
# 9776   Indian  20161219224454728         0-2
# 9777    White  20170104185305424      70-130
# 9778    White  20170109010040814       50-59
# 9779    White  20170104181520477       30-39
#
# [97800 rows x 15 columns]

# %%
MasterFrame.to_csv(os.path.join('./joined_permutations.csv'))

# %%
MasterFrame[MasterFrame['detection_enabled']==False]
# Out:
#                                                 img_path  \
# 0      crop_part1/100_1_0_20170110183726390.jpg.chip.jpg
# 1      crop_part1/100_1_2_20170105174847679.jpg.chip.jpg
# 2      crop_part1/101_1_2_20170105174739309.jpg.chip.jpg
# 3       crop_part1/10_0_0_20161220222308131.jpg.chip.jpg
# 4       crop_part1/10_0_0_20170103200329407.jpg.chip.jpg
# ...                                                  ...
# 13025                                                NaN
# 13026                                                NaN
# 13027                                                NaN
# 13028                                                NaN
# 13029                                                NaN
#
#                                          file  src_age src_gender src_race  \
# 0      100_1_0_20170110183726390.jpg.chip.jpg      100     Female    White
# 1      100_1_2_20170105174847679.jpg.chip.jpg      100     Female    Asian
# 2      101_1_2_20170105174739309.jpg.chip.jpg      101     Female    Asian
# 3       10_0_0_20161220222308131.jpg.chip.jpg       10       Male    White
# 4       10_0_0_20170103200329407.jpg.chip.jpg       10       Male    White
# ...                                       ...      ...        ...      ...
# 13025            99_1_0_20170120134718759.jpg       99     Female    White
# 13026            99_1_0_20170120221920654.jpg       99     Female    White
# 13027            99_1_1_20170120134639935.jpg       99     Female    Black
# 13028             9_0_0_20170120133313910.jpg        9       Male    White
# 13029             9_0_0_20170120133317677.jpg        9       Male    White
#
#            src_timestamp  Unnamed: 0 pred_race pred_gender pred_age_grp  \
# 0      20170110183726390         0.0     Other        Male        40-49
# 1      20170105174847679         0.0     Asian        Male        40-49
# 2      20170105174739309         0.0     Asian        Male        30-39
# 3      20161220222308131         0.0     White        Male        30-39
# 4      20170103200329407         0.0     White        Male        30-39
# ...                  ...         ...       ...         ...          ...
# 13025  20170120134718759         NaN    Indian      Female        20-29
# 13026  20170120221920654         NaN     White        Male        30-39
# 13027  20170120134639935         NaN     Other        Male       70-130
# 13028  20170120133313910         NaN     White        Male          3-9
# 13029  20170120133317677         NaN     Asian        Male        20-29
#
#        pred_age_lower  pred_age_upper pred_model  detection_enabled  \
# 0                40.0            49.0   DeepFace              False
# 1                40.0            49.0   DeepFace              False
# 2                30.0            39.0   DeepFace              False
# 3                30.0            39.0   DeepFace              False
# 4                30.0            39.0   DeepFace              False
# ...               ...             ...        ...                ...
# 13025            20.0            29.0   FairFace              False
# 13026            30.0            39.0   FairFace              False
# 13027            70.0           130.0   FairFace              False
# 13028             3.0             9.0   FairFace              False
# 13029            20.0            29.0   FairFace              False
#
#       detection_model image_type  slash src_age_grp
# 0                None    cropped  False      70-130
# 1                None    cropped  False      70-130
# 2                None    cropped  False      70-130
# 3                None    cropped  False         3-9
# 4                None    cropped  False         3-9
# ...               ...        ...    ...         ...
# 13025            None  uncropped  False      70-130
# 13026            None  uncropped  False      70-130
# 13027            None  uncropped  False      70-130
# 13028            None  uncropped  False         3-9
# 13029            None  uncropped  False         3-9
#
# [52120 rows x 18 columns]

# %%
from sklearn.metrics import confusion_matrix

from scipy.stats import chisquare

def getFiltered(frame,p_model,det_model,pred_dat,crop_type):
    filtered = frame[(frame['pred_model']==p_model)&
                     (frame['detection_model']==det_model)&
                     (~frame[pred_dat].isna())&
                     (frame['image_type']==crop_type)]
    return pd.DataFrame(filtered)

def getCorr(frame,p_model,det_model,pred_dat,crop_type,columns):
    filtered = getFiltered(frame,p_model,det_model,pred_dat,crop_type)
    filtered = filtered[columns]
    return filtered 

def get_cm(frame,p_model,det_model,src_dat,pred_dat,crop_type):
    filtered = frame[(frame['pred_model']==p_model)&
                     (frame['detection_model']==det_model)&
                     (~frame[pred_dat].isna())&
                     (frame['image_type']==crop_type)]
    #display(filtered)
    arr = list(filtered[src_dat].unique())
    #display(arr,filtered[src_dat],filtered[pred_dat])
    return confusion_matrix(filtered[src_dat],filtered[pred_dat],labels=arr)

MasterFrame = MasterFrame[
    (MasterFrame['src_race'] == 'White') | 
    (MasterFrame['src_race'] == 'Black') | 
    (MasterFrame['src_race'] == 'Asian') | 
    (MasterFrame['src_race'] == 'Indian') | 
    (MasterFrame['src_race'] == 'Other')]

#display(MasterFrame['src_race'].value_counts())

#display(MasterFrame[MasterFrame['src_race']])

#get_cm(MasterFrame,'DeepFace','None','src_race','pred_race')


x = getFiltered(MasterFrame,'DeepFace','mtcnn','pred_race','uncropped',['src_race','pred_race'])
display(x)


#chisquare(f_obs=x['src_race'],f_exp=x['pred_race'])
#c_m = ConfusionMatrix(MasterFrame[(MasterFrame['pred_model']=='FairFace')&(MasterFrame['detection_model']==None)][['pred_race','src_race']])
# Out:
#                                   img_path                           file  \
# 9780   part3/100_1_0_20170119212053665.jpg  100_1_0_20170119212053665.jpg
# 9781    part3/10_0_0_20170116201102149.jpg   10_0_0_20170116201102149.jpg
# 9782    part3/10_0_0_20170120220628194.jpg   10_0_0_20170120220628194.jpg
# 9783    part3/10_0_1_20170116225209209.jpg   10_0_1_20170116225209209.jpg
# 9784    part3/10_1_1_20170116225209209.jpg   10_1_1_20170116225209209.jpg
# ...                                    ...                            ...
# 13025   part3/99_1_0_20170120134718759.jpg   99_1_0_20170120134718759.jpg
# 13026   part3/99_1_0_20170120221920654.jpg   99_1_0_20170120221920654.jpg
# 13027   part3/99_1_1_20170120134639935.jpg   99_1_1_20170120134639935.jpg
# 13028    part3/9_0_0_20170120133313910.jpg    9_0_0_20170120133313910.jpg
# 13029    part3/9_0_0_20170120133317677.jpg    9_0_0_20170120133317677.jpg
#
#        src_age src_gender src_race      src_timestamp  Unnamed: 0 pred_race  \
# 9780       100     Female    White  20170119212053665         0.0     White
# 9781        10       Male    White  20170116201102149         0.0     White
# 9782        10       Male    White  20170120220628194         0.0     White
# 9783        10       Male    Black  20170116225209209         0.0     Black
# 9784        10     Female    Black  20170116225209209         0.0     Black
# ...        ...        ...      ...                ...         ...       ...
# 13025       99     Female    White  20170120134718759         0.0     White
# 13026       99     Female    White  20170120221920654         0.0     White
# 13027       99     Female    Black  20170120134639935         0.0    Indian
# 13028        9       Male    White  20170120133313910         0.0     White
# 13029        9       Male    White  20170120133317677         0.0     White
#
#       pred_gender pred_age_grp  pred_age_lower  pred_age_upper pred_model  \
# 9780         Male        40-49            40.0            49.0   DeepFace
# 9781         Male        20-29            20.0            29.0   DeepFace
# 9782       Female        20-29            20.0            29.0   DeepFace
# 9783       Female        30-39            30.0            39.0   DeepFace
# 9784         Male        30-39            30.0            39.0   DeepFace
# ...           ...          ...             ...             ...        ...
# 13025        Male        50-59            50.0            59.0   DeepFace
# 13026        Male        50-59            50.0            59.0   DeepFace
# 13027        Male        50-59            50.0            59.0   DeepFace
# 13028      Female        20-29            20.0            29.0   DeepFace
# 13029        Male        30-39            30.0            39.0   DeepFace
#
#        detection_enabled detection_model image_type  slash src_age_grp
# 9780                True           mtcnn  uncropped  False      70-130
# 9781                True           mtcnn  uncropped  False         3-9
# 9782                True           mtcnn  uncropped  False         3-9
# 9783                True           mtcnn  uncropped  False         3-9
# 9784                True           mtcnn  uncropped  False         3-9
# ...                  ...             ...        ...    ...         ...
# 13025               True           mtcnn  uncropped  False      70-130
# 13026               True           mtcnn  uncropped  False      70-130
# 13027               True           mtcnn  uncropped  False      70-130
# 13028               True           mtcnn  uncropped  False         3-9
# 13029               True           mtcnn  uncropped  False         3-9
#
# [3248 rows x 18 columns]
